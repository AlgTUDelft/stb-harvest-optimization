# %%
import sys
import os

func_folder_path = os.path.abspath('../functions')
sys.path.append(func_folder_path)

# %% [markdown]
# # Load data

# %% [markdown]
# ***data for exp: 2021 C1 -> 2021 C3***

# %%
from pred_data_2021 import *
# Out:
# /Users/hannah/opt/anaconda3/envs/torch38pyg/lib/python3.8/site-packages/tslearn/bases/bases.py:15: UserWarning: h5py not installed, hdf5 features will not be supported.
# Install h5py to use hdf5 features: http://docs.h5py.org/
#   warn(h5py_msg)
# Lower Bound (whisker): 0.497371158055327, Cap: 0.497371158055327
# Upper Bound (whisker): 139.78748315193502, Cap: 139.78748315193502
# the training set has 221 curves
# scaled_features (237, 71)
# test_features (237, 71)

# %% [markdown]
# ***data for exp: 2021 ALL -> 2022 C1***

# %%
from pred_data_2022 import *
# Out:
# /Users/hannah/opt/anaconda3/envs/torch38pyg/lib/python3.8/site-packages/tslearn/bases/bases.py:15: UserWarning: h5py not installed, hdf5 features will not be supported.
# Install h5py to use hdf5 features: http://docs.h5py.org/
#   warn(h5py_msg)
# Lower Bound (whisker): 0.1450297509700788, Cap: 0.1450297509700788
# Upper Bound (whisker): 142.59719748946807, Cap: 142.59719748946807
# the training set has 617 curves
# /Users/hannah/Downloads/code_to_publish/harvest_optimization/functions/pred_utils.py:95: RuntimeWarning: overflow encountered in exp
#   y = A / (1 + np.exp(-B*(x-M))) + C
# scaled_features (237, 71)
# test_features (296, 71)

# %% [markdown]
# # Experiments

# %% [markdown]
# ## k-NN with sliding windows

# %%
# %run -i ../functions/sliding_window.py
# Out:
# corr uses time: 4.182922124862671 seconds
# l2 uses time: 7.430531024932861 seconds

# %% [markdown]
# ## clustering the growth curves

# %%
# %run -i ../functions/cluster_kmeans.py

# %% [markdown]
# ## k-NN with weather conditions

# %%
# %run -i ../functions/weather_knn.py

# %% [markdown]
# ## clustering the weather conditions

# %%
# %run -i ../functions/weather_clustering.py
